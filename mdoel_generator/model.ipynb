# %%
import gempy as gp
import numpy as np
import matplotlib.pyplot as plt
import gempy_viewer as gpv
# Out:
# Setting Backend To: AvailableBackends.numpy

# %%
geo_model: gp.data.GeoModel = gp.create_geomodel(
        project_name='Salt',
        extent=[0, 800, 0, 800, -600, 0],
        resolution = [50, 50, 50],  # * Here we define the number of octree levels. If octree levels are defined, the resolution is ignored.
        importer_helper=gp.data.ImporterHelper(
        path_to_orientations="Saved points/Orientations.csv",
        path_to_surface_points="Saved points/Surface_points.csv",
         )
         )

# %%
gp.compute_model(geo_model)
# Out:
# Setting Backend To: AvailableBackends.numpy
# Chunking done: 52 chunks
# Chunking done: 7 chunks
# Solutions(4 Octree Levels, 2 DualContouringMeshes)

# %%
gpv.plot_2d(geo_model, direction=['y'], show_results=False, figsize=(9, 4))
# Out:
# d:\anaconda\envs\gempy3\lib\site-packages\gempy_viewer\API\_plot_2d_API.py:174: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   p.fig.show()

# %%
gpv.plot_2d(geo_model)
